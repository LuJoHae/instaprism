# %%
from __future__ import annotations

import instaprism

# %%
instaprism.insta_prism
# Out:
# <function instaprism._instaprism.insta_prism(bulk: 'npt.NDArray[np.float64]', reference: 'npt.NDArray[np.float64]', n_iter: 'int' = 1000) -> 'tuple[npt.NDArray[np.float64], npt.NDArray[np.float64], npt.NDArray[np.float64]]'>

# %%
instaprism.bayes_prism()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 instaprism.bayes_prism()
#
# TypeError: bayes_prism() missing 2 required positional arguments: 'bulk' and 'reference'
